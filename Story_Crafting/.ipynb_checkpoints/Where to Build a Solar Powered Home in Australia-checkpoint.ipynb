# %% [markdown]
# # Where to Build a Solar Powered Home in Australia

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset obtained from: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package

# %%
data = pd.read_csv('weatherAUS.csv',parse_dates = [0])

# %%
data.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
data.groupby(['Location']).mean().head(10)
# Out:
#                  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location
# Adelaide       12.579505  22.898934  1.566354     5.770364  7.747993
# Albany         12.948438  20.070998  2.263859     4.213345  6.657460
# Albury          9.530604  22.640872  1.914115          NaN       NaN
# AliceSprings   13.142284  29.248420  0.882850     9.026832  9.581944
# BadgerysCreek  11.131719  24.031208  2.193101          NaN       NaN
# Ballarat        7.367950  18.287266  1.740026          NaN       NaN
# Bendigo         8.593713  21.621746  1.619380     3.851730       NaN
# Brisbane       16.423807  26.448380  3.144891     5.407940  8.081170
# Cairns         21.220467  29.558849  5.742035     6.256891  7.571451
# Canberra        6.821866  20.976639  1.741720     4.399672  7.402038
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# Location
# Adelaide           36.499211      9.950125     15.471455    59.701066
# ...

# %%
sunshine_cities = data.groupby(['Location']).mean().sort_values(by='Sunshine',ascending=False)
sunshine_cities.drop(['PerthAirport','PearceRAAF'],inplace=True)

# %%
columns = ['MinTemp','MaxTemp','Rainfall','Sunshine','Humidity9am','Humidity3pm','Cloud9am','Cloud3pm','Temp9am','Temp3pm']
top_cities = sunshine_cities.head(15)[columns]

# %%
top_cities
# Out:
#                 MinTemp    MaxTemp  Rainfall  Sunshine  Humidity9am  \
# Location
# AliceSprings  13.142284  29.248420  0.882850  9.581944    39.690155
# Woomera       13.363727  26.596707  0.490405  9.047932    53.127503
# Moree         12.905853  26.950548  1.630203  8.898589    61.376705
# Perth         12.922706  25.034837  1.906295  8.784536    62.688128
# Cobar         13.149451  25.870093  1.127309  8.674364    55.152913
# Darwin        23.209305  32.540977  5.092452  8.499310    68.486216
# Mildura       10.731572  24.840944  0.945062  8.468533    64.103792
# Townsville    20.417874  29.367160  3.485592  8.457814    63.954276
# WaggaWagga     9.617182  23.031871  1.709946  8.197864    67.856953
# Brisbane      16.423807  26.448380  3.144891  8.081170    64.043587
# Adelaide      12.579505  22.898934  1.566354  7.747993    59.701066
# Nuriootpa      9.363242  21.704133  1.390343  7.672577    66.760253
# Cairns        21.220467  29.558849  5.742035  7.571451    69.936821
# ...

# %%
top_cities.plot.bar(y='Sunshine')

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(y=top_cities.index,x='Sunshine',data=top_cities, palette = 'viridis')
ax.set_title('Average Daily Sunshine in Australian Cities 2007-2017',fontsize=16)
ax.set_xlabel('Average Daily Sunshine (hrs)',fontsize=16)
ax.set_ylabel('City',fontsize=16)
# Out:
# Text(0, 0.5, 'City')

# %%
top_10 = top_cities.head(10)

# %%
top_10.index
# Out:
# Index(['AliceSprings', 'Woomera', 'Moree', 'Perth', 'Cobar', 'Darwin',
#        'Mildura', 'Townsville', 'WaggaWagga', 'Brisbane'],
#       dtype='object', name='Location')

# %% [markdown]
# Population data obtained from Google.

# %%
top_10['Population'] = (26390,150,7383,1985000,3990,132045,30016,178860,65258,2280000)
# Out:
# <ipython-input-14-ccb72e8bcc0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10['Population'] = (26390,150,7383,1985000,3990,132045,30016,178860,65258,2280000)

# %%
top_10.sort_values(by='Population',inplace=True)
# Out:
# <ipython-input-15-9130290f9582>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10.sort_values(by='Population',inplace=True)

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(y=top_10.index,x='Population',data=top_10, palette = 'viridis')
ax.set_title('Population of Australian Cities in 2016',fontsize=16)
ax.set_xlabel('Population',fontsize=16)
ax.set_ylabel('City',fontsize=16)
# Out:
# Text(0, 0.5, 'City')

# %%
top_2 = top_10.loc[['Perth','Brisbane']]

# %%
top_2
# Out:
#             MinTemp    MaxTemp  Rainfall  Sunshine  Humidity9am  Humidity3pm  \
# Location
# Perth     12.922706  25.034837  1.906295  8.784536    62.688128    46.906122
# Brisbane  16.423807  26.448380  3.144891  8.081170    64.043587    53.912209
#
#           Cloud9am  Cloud3pm    Temp9am    Temp3pm  Population
# Location
# Perth     3.383579  3.469740  18.573598  23.461748     1985000
# Brisbane  3.918546  3.879975  21.841173  24.753461     2280000

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(data=top_2,y='Humidity3pm',x=top_2.index)
ax.set_title('Daily Avg Humidity 2007-2017',fontsize=16)
ax.set_ylabel('Avg Humidity @3pm',fontsize=16)
ax.set_xlabel('City',fontsize=16)
# Out:
# Text(0.5, 0, 'City')
